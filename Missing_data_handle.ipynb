# %% [markdown]
# <a href="https://colab.research.google.com/github/sauravkumarkash1/Coursera-Full-Stack-Web-Development/blob/master/Missing_data_handle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("/content/student_data.csv")
df
# Out:
#    Id    CS  Math        Name
# 0   1  50.0  46.0     Average
# 1   2   NaN  70.0        Good
# 2   3  88.0   NaN  Execellent
# 3   4   NaN  74.0         NaN
# 4   5  63.0   NaN     Average
# 5   6   NaN   NaN  Execellent
# 6   7   NaN   NaN         NaN
# 7   8  53.0  45.0     Average
# 8   9  60.0  62.0        Good
# 9  10  55.0  65.0        Good

# %%
df.fillna(0)
# Out:
#    Id    CS  Math        Name
# 0   1  50.0  46.0     Average
# 1   2   0.0  70.0        Good
# 2   3  88.0   0.0  Execellent
# 3   4   0.0  74.0           0
# 4   5  63.0   0.0     Average
# 5   6   0.0   0.0  Execellent
# 6   7   0.0   0.0           0
# 7   8  53.0  45.0     Average
# 8   9  60.0  62.0        Good
# 9  10  55.0  65.0        Good

# %%
new_df=df.fillna({
    'CS':0,'Math':0,'Name':'No Category'
})
new_df
# Out:
#    Id    CS  Math         Name
# 0   1  50.0  46.0      Average
# 1   2   0.0  70.0         Good
# 2   3  88.0   0.0   Execellent
# 3   4   0.0  74.0  No Category
# 4   5  63.0   0.0      Average
# 5   6   0.0   0.0   Execellent
# 6   7   0.0   0.0  No Category
# 7   8  53.0  45.0      Average
# 8   9  60.0  62.0         Good
# 9  10  55.0  65.0         Good

# %%
new_df=df.fillna(method="ffill")
new_df
# Out:
#    Id    CS  Math        Name
# 0   1  50.0  46.0     Average
# 1   2  50.0  70.0        Good
# 2   3  88.0  70.0  Execellent
# 3   4  88.0  74.0  Execellent
# 4   5  63.0  74.0     Average
# 5   6  63.0  74.0  Execellent
# 6   7  63.0  74.0  Execellent
# 7   8  53.0  45.0     Average
# 8   9  60.0  62.0        Good
# 9  10  55.0  65.0        Good

# %%
new_df=df.fillna(method="bfill")
new_df
# Out:
#    Id    CS  Math        Name
# 0   1  50.0  46.0     Average
# 1   2  88.0  70.0        Good
# 2   3  88.0  74.0  Execellent
# 3   4  63.0  74.0     Average
# 4   5  63.0  45.0     Average
# 5   6  53.0  45.0  Execellent
# 6   7  53.0  45.0     Average
# 7   8  53.0  45.0     Average
# 8   9  60.0  62.0        Good
# 9  10  55.0  65.0        Good

# %%
newdf=df.fillna(method='bfill',axis="columns")    #index for row,columns for columns
newdf
# Out:
#    Id          CS        Math        Name
# 0   1          50          46     Average
# 1   2          70          70        Good
# 2   3          88  Execellent  Execellent
# 3   4          74          74         NaN
# 4   5          63     Average     Average
# 5   6  Execellent  Execellent  Execellent
# 6   7         NaN         NaN         NaN
# 7   8          53          45     Average
# 8   9          60          62        Good
# 9  10          55          65        Good

# %%
newdf=df.fillna(method='ffill',axis="columns")    #index for row,columns for columns
newdf
# Out:
#    Id  CS Math        Name
# 0   1  50   46     Average
# 1   2   2   70        Good
# 2   3  88   88  Execellent
# 3   4   4   74          74
# 4   5  63   63     Average
# 5   6   6    6  Execellent
# 6   7   7    7           7
# 7   8  53   45     Average
# 8   9  60   62        Good
# 9  10  55   65        Good

# %%
newdf=df.fillna(method='bfill',axis="index")    #index for row,columns for columns
newdf
# Out:
#    Id    CS  Math        Name
# 0   1  50.0  46.0     Average
# 1   2  88.0  70.0        Good
# 2   3  88.0  74.0  Execellent
# 3   4  63.0  74.0     Average
# 4   5  63.0  45.0     Average
# 5   6  53.0  45.0  Execellent
# 6   7  53.0  45.0     Average
# 7   8  53.0  45.0     Average
# 8   9  60.0  62.0        Good
# 9  10  55.0  65.0        Good

# %%
newdf=df.fillna(method='ffill',axis="columns")    #index for row,columns for columns
newdf
# Out:
#    Id  CS Math        Name
# 0   1  50   46     Average
# 1   2   2   70        Good
# 2   3  88   88  Execellent
# 3   4   4   74          74
# 4   5  63   63     Average
# 5   6   6    6  Execellent
# 6   7   7    7           7
# 7   8  53   45     Average
# 8   9  60   62        Good
# 9  10  55   65        Good

# %%
newdf=df.fillna(method='bfill',limit=1)    #index for row,columns for columns
newdf
# Out:
#    Id    CS  Math        Name
# 0   1  50.0  46.0     Average
# 1   2  88.0  70.0        Good
# 2   3  88.0  74.0  Execellent
# 3   4  63.0  74.0     Average
# 4   5  63.0   NaN     Average
# 5   6   NaN   NaN  Execellent
# 6   7  53.0  45.0     Average
# 7   8  53.0  45.0     Average
# 8   9  60.0  62.0        Good
# 9  10  55.0  65.0        Good

# %%
newdf=df.fillna(method='ffill',limit=3)    #index for row,columns for columns
newdf
# Out:
#    Id    CS  Math        Name
# 0   1  50.0  46.0     Average
# 1   2  50.0  70.0        Good
# 2   3  88.0  70.0  Execellent
# 3   4  88.0  74.0  Execellent
# 4   5  63.0  74.0     Average
# 5   6  63.0  74.0  Execellent
# 6   7  63.0  74.0  Execellent
# 7   8  53.0  45.0     Average
# 8   9  60.0  62.0        Good
# 9  10  55.0  65.0        Good

# %%
newdf=df.fillna(method='bfill',limit=3,inplace=True)    #index for row,columns for columns
newdf
df
# Out:
#    Id    CS  Math        Name
# 0   1  50.0  46.0     Average
# 1   2  88.0  70.0        Good
# 2   3  88.0  74.0  Execellent
# 3   4  63.0  74.0     Average
# 4   5  63.0  45.0     Average
# 5   6  53.0  45.0  Execellent
# 6   7  53.0  45.0     Average
# 7   8  53.0  45.0     Average
# 8   9  60.0  62.0        Good
# 9  10  55.0  65.0        Good

# %%
newdf=df.interpolate()
newdf
# Out:
#    Id         CS   Math        Name
# 0   1  50.000000  46.00     Average
# 1   2  69.000000  70.00        Good
# 2   3  88.000000  72.00  Execellent
# 3   4  75.500000  74.00         NaN
# 4   5  63.000000  66.75     Average
# 5   6  59.666667  59.50  Execellent
# 6   7  56.333333  52.25         NaN
# 7   8  53.000000  45.00     Average
# 8   9  60.000000  62.00        Good
# 9  10  55.000000  65.00        Good

# %%
newdf=df.dropna()
newdf
# Out:
#    Id    CS  Math     Name
# 0   1  50.0  46.0  Average
# 7   8  53.0  45.0  Average
# 8   9  60.0  62.0     Good
# 9  10  55.0  65.0     Good

# %%
newdf=df.dropna(how="all")
newdf
# Out:
#    Id    CS  Math        Name
# 0   1  50.0  46.0     Average
# 1   2   NaN  70.0        Good
# 2   3  88.0   NaN  Execellent
# 3   4   NaN  74.0         NaN
# 4   5  63.0   NaN     Average
# 5   6   NaN   NaN  Execellent
# 6   7   NaN   NaN         NaN
# 7   8  53.0  45.0     Average
# 8   9  60.0  62.0        Good
# 9  10  55.0  65.0        Good

# %%
newdf=df.dropna(thresh=3)
newdf
# Out:
#    Id    CS  Math        Name
# 0   1  50.0  46.0     Average
# 1   2   NaN  70.0        Good
# 2   3  88.0   NaN  Execellent
# 4   5  63.0   NaN     Average
# 7   8  53.0  45.0     Average
# 8   9  60.0  62.0        Good
# 9  10  55.0  65.0        Good

# %%
newdf=df.replace(np.NaN,999)
newdf
# Out:
#    Id     CS   Math        Name
# 0   1   50.0   46.0     Average
# 1   2  999.0   70.0        Good
# 2   3   88.0  999.0  Execellent
# 3   4  999.0   74.0         999
# 4   5   63.0  999.0     Average
# 5   6  999.0  999.0  Execellent
# 6   7  999.0  999.0         999
# 7   8   53.0   45.0     Average
# 8   9   60.0   62.0        Good
# 9  10   55.0   65.0        Good

# %%
newdf=df.replace(np.NaN,{
    'CS':999,'Math':100
})
newdf
# Out:
#    Id     CS   Math        Name
# 0   1   50.0   46.0     Average
# 1   2  999.0   70.0        Good
# 2   3   88.0  100.0  Execellent
# 3   4  999.0   74.0         NaN
# 4   5   63.0  100.0     Average
# 5   6  999.0  100.0  Execellent
# 6   7  999.0  100.0         NaN
# 7   8   53.0   45.0     Average
# 8   9   60.0   62.0        Good
# 9  10   55.0   65.0        Good

# %% [markdown]
# # Boston Housing Price Prediction

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import sklearn
from sklearn.linear_model import LinearRegression

# %%
from sklearn.datasets import load_boston

# %%
boston=load_boston()
print(boston)
# Out:
# {'data': array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]]), 'target': array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
# ...

# %%
boston.keys()
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])

# %%
boston['data'].shape
# Out:
# (506, 13)

# %%
bos=pd.DataFrame(boston.data)   #boston['data](we can also write in this way)
print(bos.head(2))
# Out:
#         0     1     2    3      4   ...   8      9     10     11    12
# 0  0.00632  18.0  2.31  0.0  0.538  ...  1.0  296.0  15.3  396.9  4.98
# 1  0.02731   0.0  7.07  0.0  0.469  ...  2.0  242.0  17.8  396.9  9.14
#
# [2 rows x 13 columns]

# %%
print(boston.feature_names)
# Out:
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']

# %%
print(boston.DESCR)
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %%
print(boston.target)
# Out:
# [24.  21.6 34.7 33.4 36.2 28.7 22.9 27.1 16.5 18.9 15.  18.9 21.7 20.4
#  18.2 19.9 23.1 17.5 20.2 18.2 13.6 19.6 15.2 14.5 15.6 13.9 16.6 14.8
#  18.4 21.  12.7 14.5 13.2 13.1 13.5 18.9 20.  21.  24.7 30.8 34.9 26.6
#  25.3 24.7 21.2 19.3 20.  16.6 14.4 19.4 19.7 20.5 25.  23.4 18.9 35.4
#  24.7 31.6 23.3 19.6 18.7 16.  22.2 25.  33.  23.5 19.4 22.  17.4 20.9
#  24.2 21.7 22.8 23.4 24.1 21.4 20.  20.8 21.2 20.3 28.  23.9 24.8 22.9
#  23.9 26.6 22.5 22.2 23.6 28.7 22.6 22.  22.9 25.  20.6 28.4 21.4 38.7
#  43.8 33.2 27.5 26.5 18.6 19.3 20.1 19.5 19.5 20.4 19.8 19.4 21.7 22.8
#  18.8 18.7 18.5 18.3 21.2 19.2 20.4 19.3 22.  20.3 20.5 17.3 18.8 21.4
#  15.7 16.2 18.  14.3 19.2 19.6 23.  18.4 15.6 18.1 17.4 17.1 13.3 17.8
#  14.  14.4 13.4 15.6 11.8 13.8 15.6 14.6 17.8 15.4 21.5 19.6 15.3 19.4
#  17.  15.6 13.1 41.3 24.3 23.3 27.  50.  50.  50.  22.7 25.  50.  23.8
#  23.8 22.3 17.4 19.1 23.1 23.6 22.6 29.4 23.2 24.6 29.9 37.2 39.8 36.2
# ...

# %%
bos
# Out:
#           0     1      2    3      4   ...   8      9     10      11    12
# 0    0.00632  18.0   2.31  0.0  0.538  ...  1.0  296.0  15.3  396.90  4.98
# 1    0.02731   0.0   7.07  0.0  0.469  ...  2.0  242.0  17.8  396.90  9.14
# 2    0.02729   0.0   7.07  0.0  0.469  ...  2.0  242.0  17.8  392.83  4.03
# 3    0.03237   0.0   2.18  0.0  0.458  ...  3.0  222.0  18.7  394.63  2.94
# 4    0.06905   0.0   2.18  0.0  0.458  ...  3.0  222.0  18.7  396.90  5.33
# ..       ...   ...    ...  ...    ...  ...  ...    ...   ...     ...   ...
# 501  0.06263   0.0  11.93  0.0  0.573  ...  1.0  273.0  21.0  391.99  9.67
# 502  0.04527   0.0  11.93  0.0  0.573  ...  1.0  273.0  21.0  396.90  9.08
# 503  0.06076   0.0  11.93  0.0  0.573  ...  1.0  273.0  21.0  396.90  5.64
# 504  0.10959   0.0  11.93  0.0  0.573  ...  1.0  273.0  21.0  393.45  6.48
# 505  0.04741   0.0  11.93  0.0  0.573  ...  1.0  273.0  21.0  396.90  7.88
#
# [506 rows x 13 columns]

# %%
bos.columns=boston.feature_names
bos
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX  ...  RAD    TAX  PTRATIO       B  LSTAT
# 0    0.00632  18.0   2.31   0.0  0.538  ...  1.0  296.0     15.3  396.90   4.98
# 1    0.02731   0.0   7.07   0.0  0.469  ...  2.0  242.0     17.8  396.90   9.14
# 2    0.02729   0.0   7.07   0.0  0.469  ...  2.0  242.0     17.8  392.83   4.03
# 3    0.03237   0.0   2.18   0.0  0.458  ...  3.0  222.0     18.7  394.63   2.94
# 4    0.06905   0.0   2.18   0.0  0.458  ...  3.0  222.0     18.7  396.90   5.33
# ..       ...   ...    ...   ...    ...  ...  ...    ...      ...     ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  ...  1.0  273.0     21.0  391.99   9.67
# 502  0.04527   0.0  11.93   0.0  0.573  ...  1.0  273.0     21.0  396.90   9.08
# 503  0.06076   0.0  11.93   0.0  0.573  ...  1.0  273.0     21.0  396.90   5.64
# 504  0.10959   0.0  11.93   0.0  0.573  ...  1.0  273.0     21.0  393.45   6.48
# 505  0.04741   0.0  11.93   0.0  0.573  ...  1.0  273.0     21.0  396.90   7.88
#
# ...

# %%
bos.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX  ...  RAD    TAX  PTRATIO       B  LSTAT
# 0  0.00632  18.0   2.31   0.0  0.538  ...  1.0  296.0     15.3  396.90   4.98
# 1  0.02731   0.0   7.07   0.0  0.469  ...  2.0  242.0     17.8  396.90   9.14
# 2  0.02729   0.0   7.07   0.0  0.469  ...  2.0  242.0     17.8  392.83   4.03
# 3  0.03237   0.0   2.18   0.0  0.458  ...  3.0  222.0     18.7  394.63   2.94
# 4  0.06905   0.0   2.18   0.0  0.458  ...  3.0  222.0     18.7  396.90   5.33
#
# [5 rows x 13 columns]

# %%
bos['Price']=boston.target
bos
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX  ...    TAX  PTRATIO       B  LSTAT  Price
# 0    0.00632  18.0   2.31   0.0  0.538  ...  296.0     15.3  396.90   4.98   24.0
# 1    0.02731   0.0   7.07   0.0  0.469  ...  242.0     17.8  396.90   9.14   21.6
# 2    0.02729   0.0   7.07   0.0  0.469  ...  242.0     17.8  392.83   4.03   34.7
# 3    0.03237   0.0   2.18   0.0  0.458  ...  222.0     18.7  394.63   2.94   33.4
# 4    0.06905   0.0   2.18   0.0  0.458  ...  222.0     18.7  396.90   5.33   36.2
# ..       ...   ...    ...   ...    ...  ...    ...      ...     ...    ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  ...  273.0     21.0  391.99   9.67   22.4
# 502  0.04527   0.0  11.93   0.0  0.573  ...  273.0     21.0  396.90   9.08   20.6
# 503  0.06076   0.0  11.93   0.0  0.573  ...  273.0     21.0  396.90   5.64   23.9
# 504  0.10959   0.0  11.93   0.0  0.573  ...  273.0     21.0  393.45   6.48   22.0
# ...

# %%
y=bos['Price']

# %%
x=bos.drop('Price',axis=1)
print(x.head())
print(y.head())
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX  ...  RAD    TAX  PTRATIO       B  LSTAT
# 0  0.00632  18.0   2.31   0.0  0.538  ...  1.0  296.0     15.3  396.90   4.98
# 1  0.02731   0.0   7.07   0.0  0.469  ...  2.0  242.0     17.8  396.90   9.14
# 2  0.02729   0.0   7.07   0.0  0.469  ...  2.0  242.0     17.8  392.83   4.03
# 3  0.03237   0.0   2.18   0.0  0.458  ...  3.0  222.0     18.7  394.63   2.94
# 4  0.06905   0.0   2.18   0.0  0.458  ...  3.0  222.0     18.7  396.90   5.33
#
# [5 rows x 13 columns]
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# Name: Price, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=5)

# %%
lm=LinearRegression()
lm.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred_train=lm.predict(x_train)     #actual y_train
y_pred_test=lm.predict(x_test)      #actual y_test

# %%
df=pd.DataFrame(y_pred_test,y_test)
df.head()
# Out:
#                0
# Price
# 37.6   37.467236
# 27.9   31.391547
# 22.6   27.120196
# 13.8    6.468433
# 35.2   33.629667

# %%
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y_test,y_pred_test)
print(mse)
# Out:
# 28.530458765974604

# %% [markdown]
# #Visualization

# %%
#plt.scatter(y_test,y_pred_test,c='red',marker='*')
plt.plot(x_test,lm.predict(x_test))
plt.show()
